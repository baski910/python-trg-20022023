# %%
# pip install django

# django-admin startproject sampleproject

# cd sampleproject

# python manage.py startapp simpleapp

# settings.py

INSTALLED_APPS = [
    'simpleapp',
    'django.contrib.admin',
    'django.contrib.auth',
    'django.contrib.contenttypes',
    'django.contrib.sessions',
    'django.contrib.messages',
    'django.contrib.staticfiles',
]

sampleproject/simpleapp/views.py

from django.shortcuts import render
from django.http import HttpResponse
 
def index(request):
    return  HttpResponse("<H2>HEY! Welcome to Django! </H2>")


sampleproject1/simpleapp/urls.py ( file need to be created)
from django.urls import path
from . import views
urlpatterns = [
 path('', views.index, name='index'),
]


sampleproject/urls.py

from django.contrib import admin
from django.urls import path, include

urlpatterns = [
    path('admin/', admin.site.urls),
    path('simpleapp/',include(('simpleapp.urls','simpleapp'),namespace='simpleapp'))
]


# start the server

# cd top_level_project_directory
python manage.py runserver

# access the application from browser
http://localhost:8000/simpleapp  ( get the response from view)
